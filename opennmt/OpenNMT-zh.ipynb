# %% [markdown]
# # OpenNMT
#
# The instructions and code are taken from [Neural Machine Translation (NMT) tutorial with OpenNMT-py](https://github.com/ymoslem/OpenNMT-Tutorial) by combining
# the two Jupyter notebooks together with a little bit tweaking.
#
# ### Data Gathering and Processing

# %%
# Create a directory and clone the Github MT-Preparation repository
# !mkdir -p nmt
# %cd nmt
# !git clone https://github.com/ymoslem/MT-Preparation.git
# Out:
# /home/jovyan/nmt
# Cloning into 'MT-Preparation'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 227 (delta 115), reused 186 (delta 94), pack-reused 0
# Receiving objects: 100% (227/227), 54.89 KiB | 213.00 KiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# Install the requirements
# !pip3 install -r MT-Preparation/requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/venv/lib/python3.9/site-packages (from -r MT-Preparation/requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: pandas in /home/venv/lib/python3.9/site-packages (from -r MT-Preparation/requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: sentencepiece in /home/venv/lib/python3.9/site-packages (from -r MT-Preparation/requirements.txt (line 3)) (0.1.99)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/venv/lib/python3.9/site-packages (from pandas->-r MT-Preparation/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/venv/lib/python3.9/site-packages (from pandas->-r MT-Preparation/requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/venv/lib/python3.9/site-packages (from pandas->-r MT-Preparation/requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->-r MT-Preparation/requirements.txt (line 2)) (1.16.0)

# %% [markdown]
# ### Datasets
#
# Example datasets:
#
#     EN-AR: https://object.pouta.csc.fi/OPUS-UN/v20090831/moses/ar-en.txt.zip
#     EN-ES: https://object.pouta.csc.fi/OPUS-UN/v20090831/moses/en-es.txt.zip
#     EN-FR: https://object.pouta.csc.fi/OPUS-UN/v20090831/moses/en-fr.txt.zip
#     EN-RU: https://object.pouta.csc.fi/OPUS-UN/v20090831/moses/en-ru.txt.zip
#     EN-ZH: https://object.pouta.csc.fi/OPUS-UN/v20090831/moses/en-zh.txt.zip

# %%
# Download and unzip a dataset
# !wget https://object.pouta.csc.fi/OPUS-UN/v20090831/moses/en-fr.txt.zip
# !unzip en-fr.txt.zip
# !wget https://object.pouta.csc.fi/OPUS-UN/v20090831/moses/en-zh.txt.zip
# !unzip en-zh.txt.zip
# Out:
# --2023-07-01 01:45:34--  https://object.pouta.csc.fi/OPUS-UN/v20090831/moses/en-zh.txt.zip
# Resolving object.pouta.csc.fi (object.pouta.csc.fi)... 86.50.254.19, 86.50.254.18
# Connecting to object.pouta.csc.fi (object.pouta.csc.fi)|86.50.254.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9020487 (8.6M) [application/zip]
# Saving to: ‘en-zh.txt.zip’
#
# en-zh.txt.zip       100%[===================>]   8.60M  2.60MB/s    in 3.3s
#
# 2023-07-01 01:45:39 (2.60 MB/s) - ‘en-zh.txt.zip’ saved [9020487/9020487]
#
# Archive:  en-zh.txt.zip
#   inflating: UN.en-zh.en
#   inflating: UN.en-zh.zh
#   inflating: README

# %%
import os
os.environ['HTTP_PROXY'] = 'http://proxy.vmware.com:3128'
os.environ['HTTPS_PROXY'] = 'http://proxy.vmware.com:3128'

# %%
# Filter the dataset
# Arguments: source file, target file, source language, target language
# !python3 MT-Preparation/filtering/filter.py UN.en-fr.fr UN.en-fr.en fr en
# %cd nmt
# !python3 MT-Preparation/filtering/filter.py UN.en-zh.zh UN.en-zh.en zh en
# Out:
# /home/jovyan/nmt
# Dataframe shape (rows, columns): (74067, 2)
# --- Rows with Empty Cells Deleted	--> Rows: 74067
# --- Duplicates Deleted			--> Rows: 62179
# --- Source-Copied Rows Deleted		--> Rows: 62145
# --- Too Long Source/Target Deleted	--> Rows: 3308
# --- HTML Removed			--> Rows: 3308
# --- Rows will remain in true-cased	--> Rows: 3308
# --- Rows with Empty Cells Deleted	--> Rows: 3308
# --- Rows Shuffled			--> Rows: 3308
# --- Source Saved: UN.en-zh.zh-filtered.zh
# --- Target Saved: UN.en-zh.en-filtered.en

# %% [markdown]
# ### Tokenization / Sub-wording

# %%
# !ls MT-Preparation/subwording/
# Out:
# 1-train_bpe.py	1-train_unigram.py  2-subword.py  3-desubword.py

# %%
# Train a SentencePiece model for subword tokenization
# !python3 MT-Preparation/subwording/1-train_unigram.py UN.en-fr.fr-filtered.fr UN.en-fr.en-filtered.en
# !python3 MT-Preparation/subwording/1-train_unigram.py UN.en-zh.zh-filtered.zh UN.en-zh.en-filtered.en
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=UN.en-zh.zh-filtered.zh --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: UN.en-zh.zh-filtered.zh
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: UN.en-zh.zh-filtered.zh
# trainer_interface.cc(407) LOG(INFO) Loaded all 3308 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=32100
# trainer_interface.cc(548) LOG(INFO) Done: 99.9502% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=795
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999502
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 3308 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=11423
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 1392 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 3308
# trainer_interface.cc(608) LOG(INFO) Done! 3386
# unigram_model_trainer.cc(564) LOG(INFO) Using 3386 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=1093 obj=24.4505 num_tokens=21583 num_tokens/piece=19.7466
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=1079 obj=21.6 num_tokens=21559 num_tokens/piece=19.9805
# trainer_interface.cc(686) LOG(INFO) Saving model: source.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: source.vocab
# Done, training a SentencepPiece model for the Source finished successfully!
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=UN.en-zh.en-filtered.en --model_prefix=target --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: UN.en-zh.en-filtered.en
#   input_format:
#   model_prefix: target
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 0
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(351) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(183) LOG(INFO) Loading corpus: UN.en-zh.en-filtered.en
# trainer_interface.cc(407) LOG(INFO) Loaded all 3308 sentences
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(423) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(428) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(537) LOG(INFO) all chars count=58942
# trainer_interface.cc(548) LOG(INFO) Done: 99.9508% characters are covered.
# trainer_interface.cc(558) LOG(INFO) Alphabet size=68
# trainer_interface.cc(559) LOG(INFO) Final character coverage=0.999508
# trainer_interface.cc(591) LOG(INFO) Done! preprocessed 3308 sentences.
# unigram_model_trainer.cc(222) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(226) LOG(INFO) Extracting frequent sub strings... node_num=20545
# unigram_model_trainer.cc(274) LOG(INFO) Initialized 2278 seed sentencepieces
# trainer_interface.cc(597) LOG(INFO) Tokenizing input sentences with whitespace: 3308
# trainer_interface.cc(608) LOG(INFO) Done! 3388
# unigram_model_trainer.cc(564) LOG(INFO) Using 3388 sentences for EM training
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=0 size=1105 obj=19.0133 num_tokens=18654 num_tokens/piece=16.8814
# unigram_model_trainer.cc(580) LOG(INFO) EM sub_iter=1 size=983 obj=13.2224 num_tokens=18668 num_tokens/piece=18.9908
# trainer_interface.cc(686) LOG(INFO) Saving model: target.model
# trainer_interface.cc(698) LOG(INFO) Saving vocabs: target.vocab
# Done, training a SentencepPiece model for the Target finished successfully!

# %%
# !ls
# Out:
# MT-Preparation					UN.en-zh.en-filtered.en
# README.fr					UN.en-zh.zh
# UN.en-fr.en					UN.en-zh.zh-filtered.zh
# UN.en-fr.en-filtered.en				UN.en.translated
# UN.en-fr.en-filtered.en.subword			UN.en.translated.desubword
# UN.en-fr.en-filtered.en.subword.dev		compute-bleu.py
# UN.en-fr.en-filtered.en.subword.test		config.yaml
# UN.en-fr.en-filtered.en.subword.test.desubword	en-fr.txt.zip
# UN.en-fr.en-filtered.en.subword.train		en-zh.txt.zip
# UN.en-fr.fr					models
# UN.en-fr.fr-filtered.fr				run
# UN.en-fr.fr-filtered.fr.subword			source.model
# UN.en-fr.fr-filtered.fr.subword.dev		source.vocab
# UN.en-fr.fr-filtered.fr.subword.test		target.model
# UN.en-fr.fr-filtered.fr.subword.train		target.vocab
# UN.en-zh.en					train.log

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model UN.en-fr.fr-filtered.fr UN.en-fr.en-filtered.en
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model UN.en-zh.zh-filtered.zh UN.en-zh.en-filtered.en
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: UN.en-zh.zh-filtered.zh
# Target Dataset: UN.en-zh.en-filtered.en
# Done subwording the source file! Output: UN.en-zh.zh-filtered.zh.subword
# Done subwording the target file! Output: UN.en-zh.en-filtered.en.subword

# %%
# First 3 lines before subwording
# !head -n 3 UN.en-fr.fr-filtered.fr && echo "-----" && head -n 3 UN.en-fr.en-filtered.en
# !head -n 3 UN.en-zh.zh-filtered.zh && echo "-----" && head -n 3 UN.en-zh.en-filtered.en
# Out:
# 第56/179号决议
# 第60/68号决议
# 第62/159号决议
# -----
# RESOLUTION 56/179
# RESOLUTION 60/68
# RESOLUTION 62/159

# %%
# First 3 lines after subwording
# !head -n 3 UN.en-fr.fr-filtered.fr.subword && echo "---" && head -n 3 UN.en-fr.en-filtered.en.subword
# !head -n 3 UN.en-zh.zh-filtered.zh.subword && echo "---" && head -n 3 UN.en-zh.en-filtered.en.subword
# Out:
# ▁第 5 6 / 1 7 9 号决议
# ▁第 6 0 / 6 8 号决议
# ▁第 6 2 / 1 5 9 号决议
# ---
# ▁RESOLUTION ▁ 5 6 / 1 7 9
# ▁RESOLUTION ▁ 6 0 / 6 8
# ▁RESOLUTION ▁ 6 2 / 1 5 9

# %% [markdown]
# ### Data Splitting
#
# We usually split our dataset into 3 portions:
#
#     1. training dataset - used for training the model;
#     2. development dataset - used to run regular validations during the training to help improve the model parameters; and
#     3. testing dataset - a holdout dataset used after the model finishes training to finally evaluate the model on unseen data.

# %%
# Split the dataset into training set, development set, and test set
# Development and test sets should be between 1000 and 5000 segments (here we chose 2000)
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 2000 2000 UN.en-fr.fr-filtered.fr.subword UN.en-fr.en-filtered.en.subword
# !python3 MT-Preparation/train_dev_split/train_dev_test_split.py 1000 1000 UN.en-zh.zh-filtered.zh.subword UN.en-zh.en-filtered.en.subword
# Out:
# Dataframe shape: (3308, 2)
# --- Empty Cells Deleted --> Rows: 3308
# --- Wrote Files
# Done!
# Output files
# UN.en-zh.zh-filtered.zh.subword.train
# UN.en-zh.en-filtered.en.subword.train
# UN.en-zh.zh-filtered.zh.subword.dev
# UN.en-zh.en-filtered.en.subword.dev
# UN.en-zh.zh-filtered.zh.subword.test
# UN.en-zh.en-filtered.en.subword.test

# %%
# Line count for the subworded train, dev, test datatest
# !wc -l *.subword.*
# Out:
#     2000 UN.en-fr.en-filtered.en.subword.dev
#     2000 UN.en-fr.en-filtered.en.subword.test
#     2000 UN.en-fr.en-filtered.en.subword.test.desubword
#    55719 UN.en-fr.en-filtered.en.subword.train
#     2000 UN.en-fr.fr-filtered.fr.subword.dev
#     2000 UN.en-fr.fr-filtered.fr.subword.test
#    55719 UN.en-fr.fr-filtered.fr.subword.train
#     1000 UN.en-zh.en-filtered.en.subword.dev
#     1000 UN.en-zh.en-filtered.en.subword.test
#     1308 UN.en-zh.en-filtered.en.subword.train
#     1000 UN.en-zh.zh-filtered.zh.subword.dev
#     1000 UN.en-zh.zh-filtered.zh.subword.test
#     1308 UN.en-zh.zh-filtered.zh.subword.train
#   128054 total

# %%
# Check the first and last line from each dataset

# -------------------------------------------
# Change this cell to print your name
# !echo -e "My name is: FirstName SecondName \n"
# -------------------------------------------

# !echo "---First line---"
# !head -n 1 *.{train,dev,test}

# !echo -e "\n---Last line---"
# !tail -n 1 *.{train,dev,test}
# Out:
# My name is: FirstName SecondName
#
# ---First line---
# ==> UN.en-fr.en-filtered.en.subword.train <==
# ▁( l ) ▁The ▁report ▁of ▁the ▁Secretary - General ▁entitled ▁" R oad ▁map ▁towards ▁implementation ▁of ▁the ▁Unit ed ▁Nations ▁Millennium ▁Declaration ", A / 5 6 / 3 2 6 ; ▁see ▁also ▁the ▁report ▁of ▁the ▁Secretary - General ▁on ▁the ▁implementation ▁of ▁the ▁Unit ed ▁Nations ▁Millennium ▁Declaration ▁( A / 5 8 / 3 2 3 ), ▁para . ▁ 2 3 . ▁in ▁particular ▁paragraphs ▁ 5 6 ▁to ▁ 6 1 ▁thereof ,
#
# ==> UN.en-fr.fr-filtered.fr.subword.train <==
# ▁l ) ▁Le ▁rapport ▁du ▁Secrétaire ▁général ▁intitulé ▁« ▁Plan ▁de ▁campagne ▁pour ▁la ▁mise ▁en ▁œuvre ▁de ▁la ▁Déclaration ▁du ▁Millénaire ▁» A / 5 6 / 3 2 6 ▁; ▁voir ▁également ▁le ▁rapport ▁du ▁Secrétaire ▁général ▁sur ▁l ' application ▁de ▁la ▁Déclaration ▁du ▁Millénaire ▁adoptée ▁par ▁l ' Organisation ▁des ▁Nations ▁Unies ▁( A / 5 8 / 3 2 3 ), ▁par . ▁ 2 3 ., ▁en ▁particulier ▁ses ▁paragraphe s ▁ 5 6 ▁à ▁ 6 1 ,
#
# ==> UN.en-zh.en-filtered.en.subword.train <==
# ▁RESOLUTION ▁ 5 6 / 1 7 9
#
# ==> UN.en-zh.zh-filtered.zh.subword.train <==
# ▁第 5 6 / 1 7 9 号决议
#
# ==> UN.en-fr.en-filtered.en.subword.dev <==
# ▁ 5 . ▁Reaffirms ▁its ▁decision , ▁with ▁a ▁view ▁to ▁further ▁development ▁of ▁the ▁Register , ▁to ▁keep ▁the ▁scope ▁of ▁and ▁participation ▁in ▁the ▁Register ▁under ▁review ▁and , ▁to ▁that ▁end :
#
# ==> UN.en-fr.fr-filtered.fr.subword.dev <==
# ▁ 5 . ▁Réaffirme ▁sa ▁décision ▁de ▁continuer ▁à ▁examiner ▁la ▁portée ▁du ▁Registre ▁ainsi ▁que ▁la ▁participation ▁à ▁celui - ci , ▁en ▁vue ▁de ▁l ' améliorer ▁encore , ▁et ▁à ▁cet ▁effet :
#
# ==> UN.en-zh.en-filtered.en.subword.dev <==
# ▁RESOLUTION ▁ 5 8 / 8 4
#
# ==> UN.en-zh.zh-filtered.zh.subword.dev <==
# ▁第 5 8 / 8 4 号决议
#
# ==> UN.en-fr.en-filtered.en.subword.test <==
# ▁Recalling ▁also ▁Security ▁Council ▁resolution ▁ 1 4 1 0 ▁( 2 0 0 2 ) ▁of ▁ 1 7 ▁May ▁ 2 0 0 2 , ▁by ▁which ▁the ▁Council ▁established ▁the ▁Unit ed ▁Nations ▁Mission ▁of ▁Support ▁in ▁East ▁Timor ▁as ▁of ▁ 2 0 ▁May ▁ 2 0 0 2 ▁for ▁an ▁initial ▁period ▁of ▁twelve ▁months , ▁and ▁its ▁subsequent ▁resolution ▁ 1 4 8 0 ▁( 2 0 0 3 ) ▁of ▁ 1 9 ▁May ▁ 2 0 0 3 , ▁by ▁which ▁the ▁Council ▁extended ▁the ▁mandate ▁of ▁the ▁Mission ▁unti l ▁ 2 0 ▁May ▁ 2 0 0 4 ,
#
# ==> UN.en-fr.fr-filtered.fr.subword.test <==
# ▁Rappelant ▁également ▁la ▁résolution ▁ 1 4 1 0 ▁( 2 0 0 2 ) ▁du ▁ 1 7 ▁mai ▁ 2 0 0 2 , ▁par ▁laquelle ▁le ▁Conseil ▁de ▁sécurité ▁a ▁créé ▁la ▁Mission ▁d ' appui ▁des ▁Nations ▁Unies ▁au ▁Timor ▁oriental ▁pour ▁une ▁période ▁initiale ▁de ▁douz e ▁mois ▁commençant ▁le ▁ 2 0 ▁mai ▁ 2 0 0 2 , ▁et ▁la ▁résolution ▁ 1 4 8 0 ▁( 2 0 0 3 ) ▁du ▁ 1 9 ▁mai ▁ 2 0 0 3 , ▁par ▁laquelle ▁il ▁a ▁prorogé ▁le ▁mandat ▁de ▁la ▁Mission ▁jus qu ' au ▁ 2 0 ▁mai ▁ 2 0 0 4 ,
#
# ==> UN.en-zh.en-filtered.en.subword.test <==
# ▁RESOLUTION ▁ 6 2 / 2 2 4
#
# ==> UN.en-zh.zh-filtered.zh.subword.test <==
# ▁第 6 2 / 2 2 4 号决议
#
# ---Last line---
# ==> UN.en-fr.en-filtered.en.subword.train <==
# ▁Tak ing ▁into ▁account ▁the ▁deliberations ▁at ▁the ▁ 2 0 0 0 ▁substantive ▁session ▁of ▁the ▁Disarmament ▁Commission ▁in ▁Work ing ▁Group ▁II ▁on ▁agenda ▁item ▁ 5 , ▁entitled ▁" Practic al ▁confidence - building ▁measures ▁in ▁the ▁field ▁of ▁convention al ▁arms ", See ▁Official ▁Record s ▁of ▁the ▁General ▁Assembly , ▁Fift y - fifth ▁Session , ▁Supplement ▁No . ▁ 4 2 ▁( A / 5 5 / 4 2 ), ▁para . ▁ 2 9 . ▁and ▁encouraging ▁the ▁Disarmament ▁Commission ▁to ▁continue ▁its ▁efforts ▁aimed ▁at ▁the ▁identification ▁of ▁such ▁measures ,
#
# ==> UN.en-fr.fr-filtered.fr.subword.train <==
# ▁Pren ant ▁en ▁considération ▁les ▁débats ▁tenus ▁par ▁le ▁Groupe ▁de ▁travail ▁II , ▁lors ▁de ▁la ▁session ▁de ▁fond ▁de ▁ 2 0 0 0 ▁de ▁la ▁Commission ▁du ▁désarmement , ▁sur ▁le ▁point ▁ 5 ▁de ▁l ' ordre ▁du ▁jour ▁intitulé ▁« Mesure s ▁concrètes ▁de ▁confiance ▁d ans ▁le ▁domaine ▁des ▁armes ▁classiques Voir ▁Document s ▁officiels ▁de ▁l ' Assemblée ▁générale , ▁cinquante - cinquième ▁session , ▁S upplément ▁no ▁ 4 2 ▁( A / 5 5 / 4 2 ), ▁par . ▁ 2 9 .», ▁et ▁encourageant ▁la ▁Commission ▁à ▁continuer ▁de ▁s ' efforcer ▁de ▁définir ▁de ▁telle s ▁mesures ,
#
# ==> UN.en-zh.en-filtered.en.subword.train <==
# ▁RESOLUTION ▁ 5 5 / 1 4 3
#
# ==> UN.en-zh.zh-filtered.zh.subword.train <==
# ▁第 5 5 / 1 4 3 号决议
#
# ==> UN.en-fr.en-filtered.en.subword.dev <==
# ▁Abst aining : ▁Albania , ▁A ndor ra , ▁Australia , ▁Belgium , ▁Bolivia , ▁Bosnia ▁and ▁Herzegovina , ▁Bulgaria , ▁Canada , ▁China , ▁Croatia , ▁C ze ch ▁Republic , ▁Denmark , ▁Estonia , ▁Georgia , ▁Greece , ▁Hungary , ▁Israel , ▁Latvia , ▁Lithuania , ▁Luxembourg , ▁M arshall ▁Islands , ▁Micronesia ▁( Federat ed ▁States ▁of ), ▁Moldova , ▁Montenegro , ▁Netherlands , ▁Palau , ▁Poland , ▁Republic ▁of ▁Korea , ▁Romania , ▁Serbia , ▁Slovakia , ▁Slovenia , ▁the ▁former ▁Yugoslav ▁Republic ▁of ▁Macedonia , ▁Tonga , ▁Turkey , ▁Ukraine
#
# ==> UN.en-fr.fr-filtered.fr.subword.dev <==
# ▁Se ▁sont ▁abstenus ▁: ▁ Albanie , ▁And orre , ▁Australie , ▁Belg ique , ▁Bolivie , ▁Bosnie - Herzégovine , ▁Bulgarie , ▁Canada , ▁Chine , ▁Croatie , ▁Dan e mark , ▁Estonie , ▁ex - République ▁yougoslave ▁de ▁Macédoine , ▁Géorgie , ▁Grèce , ▁Hongrie , ▁ Î les ▁Marshall , ▁Isra ë l , ▁Lettonie , ▁Lituanie , ▁Luxembourg , ▁Micronésie ▁( États ▁fédér és ▁de ), ▁Moldova , ▁Monténégro , ▁Palaos , ▁Pays - Bas , ▁Pologne , ▁République ▁de ▁Corée , ▁République ▁tchèque , ▁Roumanie , ▁Serbie , ▁Slovaquie , ▁Slovénie , ▁Tonga , ▁Turquie , ▁Ukraine
#
# ==> UN.en-zh.en-filtered.en.subword.dev <==
# ▁Policy ▁co ordination
#
# ==> UN.en-zh.zh-filtered.zh.subword.dev <==
# ▁政策 协调
#
# ==> UN.en-fr.en-filtered.en.subword.test <==
# ▁ 2 1 . ▁Stresses ▁the ▁need ▁for ▁the ▁continued ▁regular ▁exchange ▁of ▁views ▁between ▁the ▁Committee , ▁the ▁Special ▁Rapporteur ▁and ▁other ▁relevant ▁Unit ed ▁Nations ▁mechanisms ▁and ▁bodies , ▁as ▁well ▁as ▁for ▁the ▁pursu ance ▁of ▁cooperation ▁with ▁relevant ▁Unit ed ▁Nations ▁programmes , ▁notably ▁the ▁Unit ed ▁Nations ▁Crime ▁Prevention ▁and ▁Criminal ▁Justice ▁Programme , ▁with ▁a ▁view ▁to ▁enhancing ▁further ▁their ▁effectiveness ▁and ▁cooperation ▁on ▁issues ▁relating ▁to ▁torture , ▁inter ▁alia , ▁by ▁improving ▁their ▁coordination ;
#
# ==> UN.en-fr.fr-filtered.fr.subword.test <==
# ▁ 2 1 . ▁Souligne ▁que ▁les ▁échanges ▁de ▁vues ▁réguliers ▁entre ▁le ▁Comité , ▁le ▁Rapporteur ▁spécial ▁et ▁les ▁autres ▁instances ▁et ▁organes ▁compétents ▁des ▁Nations ▁Unies , ▁ainsi ▁que ▁la ▁coopération ▁avec ▁les ▁programmes ▁pertinents ▁des ▁Nations ▁Unies , ▁en ▁particulier ▁le ▁Programme ▁des ▁Nations ▁Unies ▁en ▁matière ▁de ▁prévention ▁du ▁crime ▁et ▁de ▁justice ▁pénale , ▁doivent ▁continuer , ▁l ' objectif ▁étant ▁de ▁ rendre ▁ces ▁échanges ▁de ▁vues ▁et ▁ cette ▁coopération ▁plus ▁efficaces ▁en ▁ce ▁qui ▁concerne ▁les ▁questions ▁relatives ▁à ▁la ▁torture , ▁gr â ce ▁notamment ▁à ▁une ▁meilleure ▁coordination ;
#
# ==> UN.en-zh.en-filtered.en.subword.test <==
# ▁RESOLUTION ▁ 5 8 / 1 1 2
#
# ==> UN.en-zh.zh-filtered.zh.subword.test <==
# ▁第 5 8 / 1 1 2 号决议

# %%
# Install OpenNMT-py 3.x
# !pip3 install OpenNMT-py
# Out:
# Collecting OpenNMT-py
#   Downloading OpenNMT_py-3.3-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.9/242.9 kB 518.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: torch<2.1,>=1.13 in /home/venv/lib/python3.9/site-packages (from OpenNMT-py) (2.0.0+cu117)
# Collecting configargparse (from OpenNMT-py)
#   Downloading ConfigArgParse-1.5.5-py3-none-any.whl (25 kB)
# Requirement already satisfied: ctranslate2<4,>=3.2 in /home/venv/lib/python3.9/site-packages (from OpenNMT-py) (3.16.0)
# Requirement already satisfied: tensorboard>=2.3 in /home/venv/lib/python3.9/site-packages (from OpenNMT-py) (2.12.3)
# Requirement already satisfied: flask in /home/venv/lib/python3.9/site-packages (from OpenNMT-py) (2.3.2)
# Collecting waitress (from OpenNMT-py)
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.5 MB/s eta 0:00:00
# Collecting pyonmttok<2,>=1.35 (from OpenNMT-py)
#   Downloading pyonmttok-1.37.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 3.3 MB/s eta 0:00:0000:0100:01m
# Requirement already satisfied: pyyaml in /home/venv/lib/python3.9/site-packages (from OpenNMT-py) (6.0)
# Collecting sacrebleu (from OpenNMT-py)
#   Using cached sacrebleu-2.3.1-py3-none-any.whl (118 kB)
# Collecting rapidfuzz (from OpenNMT-py)
#   Downloading rapidfuzz-3.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.3 MB/s eta 0:00:0000:0100:01
# Collecting pyahocorasick (from OpenNMT-py)
#   Downloading pyahocorasick-2.0.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 11.3 MB/s eta 0:00:00
# Collecting fasttext-wheel (from OpenNMT-py)
#   Downloading fasttext_wheel-0.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 2.2 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: numpy in /home/venv/lib/python3.9/site-packages (from ctranslate2<4,>=3.2->OpenNMT-py) (1.23.5)
# Requirement already satisfied: absl-py>=0.4 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (1.54.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (2.19.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (4.23.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (2.30.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (2.3.4)
# Requirement already satisfied: wheel>=0.26 in /home/venv/lib/python3.9/site-packages (from tensorboard>=2.3->OpenNMT-py) (0.40.0)
# Requirement already satisfied: filelock in /home/venv/lib/python3.9/site-packages (from torch<2.1,>=1.13->OpenNMT-py) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/venv/lib/python3.9/site-packages (from torch<2.1,>=1.13->OpenNMT-py) (4.5.0)
# Requirement already satisfied: sympy in /home/venv/lib/python3.9/site-packages (from torch<2.1,>=1.13->OpenNMT-py) (1.12)
# Requirement already satisfied: networkx in /home/venv/lib/python3.9/site-packages (from torch<2.1,>=1.13->OpenNMT-py) (3.1)
# Requirement already satisfied: jinja2 in /home/venv/lib/python3.9/site-packages (from torch<2.1,>=1.13->OpenNMT-py) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /home/venv/lib/python3.9/site-packages (from torch<2.1,>=1.13->OpenNMT-py) (2.0.0)
# Requirement already satisfied: cmake in /home/venv/lib/python3.9/site-packages (from triton==2.0.0->torch<2.1,>=1.13->OpenNMT-py) (3.26.3)
# Requirement already satisfied: lit in /home/venv/lib/python3.9/site-packages (from triton==2.0.0->torch<2.1,>=1.13->OpenNMT-py) (16.0.3)
# Collecting pybind11>=2.2 (from fasttext-wheel->OpenNMT-py)
#   Downloading pybind11-2.10.4-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/venv/lib/python3.9/site-packages (from flask->OpenNMT-py) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /home/venv/lib/python3.9/site-packages (from flask->OpenNMT-py) (8.1.3)
# Requirement already satisfied: blinker>=1.6.2 in /home/venv/lib/python3.9/site-packages (from flask->OpenNMT-py) (1.6.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/venv/lib/python3.9/site-packages (from flask->OpenNMT-py) (6.6.0)
# Collecting portalocker (from sacrebleu->OpenNMT-py)
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /home/venv/lib/python3.9/site-packages (from sacrebleu->OpenNMT-py) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /home/venv/lib/python3.9/site-packages (from sacrebleu->OpenNMT-py) (0.9.0)
# Collecting colorama (from sacrebleu->OpenNMT-py)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting lxml (from sacrebleu->OpenNMT-py)
#   Using cached lxml-4.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /home/venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/venv/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.3->OpenNMT-py) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /home/venv/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->flask->OpenNMT-py) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/venv/lib/python3.9/site-packages (from jinja2->torch<2.1,>=1.13->OpenNMT-py) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard>=2.3->OpenNMT-py) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /home/venv/lib/python3.9/site-packages (from sympy->torch<2.1,>=1.13->OpenNMT-py) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.3->OpenNMT-py) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.3->OpenNMT-py) (3.2.2)
# Installing collected packages: waitress, rapidfuzz, pyonmttok, pybind11, pyahocorasick, portalocker, lxml, configargparse, colorama, sacrebleu, fasttext-wheel, OpenNMT-py
# Successfully installed OpenNMT-py-3.3 colorama-0.4.6 configargparse-1.5.5 fasttext-wheel-0.9.2 lxml-4.9.2 portalocker-2.7.0 pyahocorasick-2.0.0 pybind11-2.10.4 pyonmttok-1.37.1 rapidfuzz-3.1.1 sacrebleu-2.3.1 waitress-2.1.2

# %%
# Open the folder where you saved your prepapred datasets from the first exercise
# !ls
# Out:
# MT-Preparation
# README.fr
# UN.en-fr.en
# UN.en-fr.en-filtered.en
# UN.en-fr.en-filtered.en.subword
# UN.en-fr.en-filtered.en.subword.dev
# UN.en-fr.en-filtered.en.subword.test
# UN.en-fr.en-filtered.en.subword.test.desubword
# UN.en-fr.en-filtered.en.subword.train
# UN.en-fr.fr
# UN.en-fr.fr-filtered.fr
# UN.en-fr.fr-filtered.fr.subword
# UN.en-fr.fr-filtered.fr.subword.dev
# UN.en-fr.fr-filtered.fr.subword.test
# UN.en-fr.fr-filtered.fr.subword.train
# UN.en-zh.en
# UN.en-zh.en-filtered.en
# UN.en-zh.en-filtered.en.subword
# UN.en-zh.en-filtered.en.subword.dev
# UN.en-zh.en-filtered.en.subword.test
# UN.en-zh.en-filtered.en.subword.train
# UN.en-zh.zh
# UN.en-zh.zh-filtered.zh
# UN.en-zh.zh-filtered.zh.subword
# UN.en-zh.zh-filtered.zh.subword.dev
# UN.en-zh.zh-filtered.zh.subword.test
# UN.en-zh.zh-filtered.zh.subword.train
# UN.en.translated
# UN.en.translated.desubword
# compute-bleu.py
# config.yaml
# en-fr.txt.zip
# en-zh.txt.zip
# models
# run
# source.model
# source.vocab
# target.model
# target.vocab
# train.log

# %%
pwd
# Out:
# '/home/jovyan/nmt'

# %% [markdown]
# ### Create the Training Configuration File
#
# The following config file matches most of the recommended values for the Transformer model [Vaswani et al., 2017](https://arxiv.org/abs/1706.03762). As the current dataset is small, we reduced the following values:
#
#     train_steps - for datasets with a few millions of sentences, consider using a value between 100000 and 200000, or more! Enabling the option early_stopping can help stop the training when there is no considerable improvement.
#     valid_steps - 10000 can be good if the value train_steps is big enough.
#     warmup_steps - obviously, its value must be less than train_steps. Try 4000 and 8000 values.

# %%
# Create the YAML configuration file
# On a regular machine, you can create it manually or with nano
# Note here we are using some smaller values because the dataset is small
# For larger datasets, consider increasing: train_steps, valid_steps, warmup_steps, save_checkpoint_steps, keep_checkpoint

config = '''# config.yaml


## Where the samples will be written
save_data: run

# Training files
data:
    corpus_1:
        path_src: UN.en-zh.zh-filtered.zh.subword.train
        path_tgt: UN.en-zh.en-filtered.en.subword.train
        transforms: [filtertoolong]
    valid:
        path_src: UN.en-zh.zh-filtered.zh.subword.dev
        path_tgt: UN.en-zh.en-filtered.en.subword.dev
        transforms: [filtertoolong]

# Vocabulary files, generated by onmt_build_vocab
src_vocab: run/source.vocab
tgt_vocab: run/target.vocab

# Vocabulary size - should be the same as in sentence piece
src_vocab_size: 50000
tgt_vocab_size: 50000

# Filter out source/target longer than n if [filtertoolong] enabled
src_seq_length: 150
src_seq_length: 150

# Tokenization options
src_subword_model: source.model
tgt_subword_model: target.model

# Where to save the log file and the output models/checkpoints
log_file: train.log
save_model: models/model.zhen

# Stop training if it does not imporve after n validations
early_stopping: 4

# Default: 5000 - Save a model checkpoint for each n
save_checkpoint_steps: 1000

# To save space, limit checkpoints to last n
# keep_checkpoint: 3

seed: 3435

# Default: 100000 - Train the model to max n steps 
# Increase to 200000 or more for large datasets
# For fine-tuning, add up the required steps to the original steps
train_steps: 3000

# Default: 10000 - Run validation after n steps
valid_steps: 1000

# Default: 4000 - for large datasets, try up to 8000
warmup_steps: 1000
report_every: 100

# Number of GPUs, and IDs of GPUs
world_size: 1
gpu_ranks: [0]

# Batching
bucket_size: 262144
num_workers: 0  # Default: 2, set to 0 when RAM out of memory
batch_type: "tokens"
batch_size: 4096   # Tokens per batch, change when CUDA out of memory
valid_batch_size: 2048
max_generator_batches: 2
accum_count: [4]
accum_steps: [0]

# Optimization
model_dtype: "fp16"
optim: "adam"
learning_rate: 2
# warmup_steps: 8000
decay_method: "noam"
adam_beta2: 0.998
max_grad_norm: 0
label_smoothing: 0.1
param_init: 0
param_init_glorot: true
normalization: "tokens"

# Model
encoder_type: transformer
decoder_type: transformer
position_encoding: true
enc_layers: 6
dec_layers: 6
heads: 8
hidden_size: 512
word_vec_size: 512
transformer_ff: 2048
dropout_steps: [0]
dropout: [0.1]
attention_dropout: [0.1]
'''

with open("config.yaml", "w") as config_yaml:
  config_yaml.write(config)

# %%
# [Optional] Check the content of the configuration file
# !cat config.yaml
# Out:
# # config.yaml
#
#
# ## Where the samples will be written
# save_data: run
#
# # Training files
# data:
#     corpus_1:
#         path_src: UN.en-zh.zh-filtered.zh.subword.train
#         path_tgt: UN.en-zh.en-filtered.en.subword.train
#         transforms: [filtertoolong]
#     valid:
#         path_src: UN.en-zh.zh-filtered.zh.subword.dev
#         path_tgt: UN.en-zh.en-filtered.en.subword.dev
#         transforms: [filtertoolong]
#
# # Vocabulary files, generated by onmt_build_vocab
# src_vocab: run/source.vocab
# tgt_vocab: run/target.vocab
#
# # Vocabulary size - should be the same as in sentence piece
# src_vocab_size: 50000
# tgt_vocab_size: 50000
#
# # Filter out source/target longer than n if [filtertoolong] enabled
# src_seq_length: 150
# src_seq_length: 150
#
# # Tokenization options
# src_subword_model: source.model
# tgt_subword_model: target.model
#
# # Where to save the log file and the output models/checkpoints
# log_file: train.log
# save_model: models/model.zhen
#
# # Stop training if it does not imporve after n validations
# early_stopping: 4
#
# # Default: 5000 - Save a model checkpoint for each n
# save_checkpoint_steps: 1000
#
# # To save space, limit checkpoints to last n
# # keep_checkpoint: 3
#
# seed: 3435
#
# # Default: 100000 - Train the model to max n steps
# # Increase to 200000 or more for large datasets
# # For fine-tuning, add up the required steps to the original steps
# train_steps: 3000
#
# # Default: 10000 - Run validation after n steps
# valid_steps: 1000
#
# # Default: 4000 - for large datasets, try up to 8000
# warmup_steps: 1000
# report_every: 100
#
# # Number of GPUs, and IDs of GPUs
# world_size: 1
# gpu_ranks: [0]
#
# # Batching
# bucket_size: 262144
# num_workers: 0  # Default: 2, set to 0 when RAM out of memory
# batch_type: "tokens"
# batch_size: 4096   # Tokens per batch, change when CUDA out of memory
# valid_batch_size: 2048
# max_generator_batches: 2
# accum_count: [4]
# accum_steps: [0]
#
# # Optimization
# model_dtype: "fp16"
# optim: "adam"
# learning_rate: 2
# # warmup_steps: 8000
# decay_method: "noam"
# adam_beta2: 0.998
# max_grad_norm: 0
# label_smoothing: 0.1
# param_init: 0
# param_init_glorot: true
# normalization: "tokens"
#
# # Model
# encoder_type: transformer
# decoder_type: transformer
# position_encoding: true
# enc_layers: 6
# dec_layers: 6
# heads: 8
# hidden_size: 512
# word_vec_size: 512
# transformer_ff: 2048
# dropout_steps: [0]
# dropout: [0.1]
# attention_dropout: [0.1]

# %% [markdown]
# ### Build Vocabulary

# %%
# Find the number of CPUs/cores on the machine
# !nproc --all
# Out:
# 16

# %%
# Build Vocabulary

# -config: path to your config.yaml file
# -n_sample: use -1 to build vocabulary on all the segment in the training dataset
# -num_threads: change it to match the number of CPUs to run it faster

# !rm run/*
# !onmt_build_vocab -config config.yaml -n_sample -1 -num_threads 4
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-07-01 02:30:00,753 INFO] Counter vocab from -1 samples.
# [2023-07-01 02:30:00,753 INFO] n_sample=-1: Build vocab on full datasets.
# [2023-07-01 02:30:00,792 INFO] * Transform statistics for corpus_1(25.00%):
# 			* FilterTooLongStats(filtered=1)
#
# [2023-07-01 02:30:00,805 INFO] Counters src: 681
# [2023-07-01 02:30:00,806 INFO] Counters tgt: 607

# %%
# Check if the GPU is active
# !nvidia-smi -L
# Out:
# GPU 0: GRID V100-16C (UUID: GPU-87e669c5-28e4-11b2-bca1-dacc96a729c6)

# %%
# Check if the GPU is visable to PyTorch

import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

gpu_memory = torch.cuda.mem_get_info(0)
print("Free GPU memory:", gpu_memory[0]/1024**2, "out of:", gpu_memory[1]/1024**2)
# Out:
# True
# GRID V100-16C
# Free GPU memory: 14907.546875 out of: 16384.0

# %% [markdown]
# ### Training

# %%
# !rm -rf models/

# %%
# Train the NMT model
# !onmt_train -config config.yaml
# Out:
# [2023-07-01 02:30:21,028 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2023-07-01 02:30:21,029 INFO] Parsed 2 corpora from -data.
# [2023-07-01 02:30:21,029 INFO] Get special vocabs from Transforms: {'src': [], 'tgt': []}.
# [2023-07-01 02:30:21,032 INFO] The first 10 tokens of the vocabs are:['<unk>', '<blank>', '<s>', '</s>', '/', '5', '▁第', '号决议', '1', '6']
# [2023-07-01 02:30:21,032 INFO] The decoder start token is: <s>
# [2023-07-01 02:30:21,032 INFO] Building model...
# [2023-07-01 02:30:21,443 INFO] Switching model to float32 for amp/apex_amp
# [2023-07-01 02:30:21,443 INFO] Non quantized layer compute is fp16
# [2023-07-01 02:30:22,486 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(688, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): ModuleList(
#       (0-5): 6 x TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=False)
#           (w_2): Linear(in_features=2048, out_features=512, bias=False)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(616, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#     (transformer_layers): ModuleList(
#       (0-5): 6 x TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=512, out_features=2048, bias=False)
#           (w_2): Linear(in_features=2048, out_features=512, bias=False)
#           (layer_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=False)
#           (linear_values): Linear(in_features=512, out_features=512, bias=False)
#           (linear_query): Linear(in_features=512, out_features=512, bias=False)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=512, out_features=512, bias=False)
#         )
#         (layer_norm_2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       )
#     )
#   )
#   (generator): Linear(in_features=512, out_features=616, bias=True)
# )
# [2023-07-01 02:30:22,488 INFO] encoder: 19239936
# [2023-07-01 02:30:22,488 INFO] decoder: 25816680
# [2023-07-01 02:30:22,488 INFO] * number of parameters: 45056616
# [2023-07-01 02:30:22,489 INFO] Trainable parameters = {'torch.float32': 45056616, 'torch.float16': 0, 'torch.uint8': 0, 'torch.int8': 0}
# [2023-07-01 02:30:22,489 INFO] Non trainable parameters = {'torch.float32': 0, 'torch.float16': 0, 'torch.uint8': 0, 'torch.int8': 0}
# [2023-07-01 02:30:22,489 INFO]  * src vocab size = 688
# [2023-07-01 02:30:22,489 INFO]  * tgt vocab size = 616
# [2023-07-01 02:30:22,491 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 1
# [2023-07-01 02:30:22,492 INFO] Starting training on GPU: [0]
# [2023-07-01 02:30:22,492 INFO] Start training loop and validate every 1000 steps...
# [2023-07-01 02:30:22,492 INFO] Scoring with: TransformPipe(FilterTooLongTransform(src_seq_length=150, tgt_seq_length=192))
# [2023-07-01 02:30:22,506 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 2
# [2023-07-01 02:30:22,520 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 3
# [2023-07-01 02:30:22,533 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 4
# [2023-07-01 02:30:22,546 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 5
# [2023-07-01 02:30:22,559 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 6
# [2023-07-01 02:30:22,574 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 7
# [2023-07-01 02:30:22,588 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 8
# [2023-07-01 02:30:22,602 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9
# [2023-07-01 02:30:22,616 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 10
# [2023-07-01 02:30:22,697 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 11
# [2023-07-01 02:30:22,711 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 12
# [2023-07-01 02:30:22,726 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 13
# [2023-07-01 02:30:22,741 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 14
# [2023-07-01 02:30:22,756 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 15
# [2023-07-01 02:30:22,770 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 16
# [2023-07-01 02:30:22,784 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 17
# [2023-07-01 02:30:22,798 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 18
# [2023-07-01 02:30:22,812 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 19
# [2023-07-01 02:30:22,826 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 20
# [2023-07-01 02:30:22,840 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 21
# [2023-07-01 02:30:22,944 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 22
# [2023-07-01 02:30:22,957 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 23
# [2023-07-01 02:30:22,969 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 24
# [2023-07-01 02:30:22,982 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 25
# [2023-07-01 02:30:22,995 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 26
# [2023-07-01 02:30:23,007 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 27
# [2023-07-01 02:30:23,020 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 28
# [2023-07-01 02:30:23,032 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 29
# [2023-07-01 02:30:23,045 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 30
# [2023-07-01 02:30:23,058 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 31
# [2023-07-01 02:30:23,071 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 32
# [2023-07-01 02:30:23,084 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 33
# [2023-07-01 02:30:23,210 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 34
# [2023-07-01 02:30:23,223 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 35
# [2023-07-01 02:30:23,237 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 36
# [2023-07-01 02:30:23,250 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 37
# [2023-07-01 02:30:23,262 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 38
# [2023-07-01 02:30:23,277 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 39
# [2023-07-01 02:30:23,291 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 40
# [2023-07-01 02:30:23,305 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 41
# [2023-07-01 02:30:23,318 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 42
# [2023-07-01 02:30:23,331 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 43
# [2023-07-01 02:30:23,344 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 44
# [2023-07-01 02:30:23,357 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 45
# [2023-07-01 02:30:23,370 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 46
# [2023-07-01 02:30:23,382 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 47
# [2023-07-01 02:30:23,532 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 48
# [2023-07-01 02:30:23,545 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 49
# [2023-07-01 02:30:23,558 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 50
# [2023-07-01 02:30:23,572 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 51
# [2023-07-01 02:30:23,583 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 52
# [2023-07-01 02:30:23,598 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 53
# [2023-07-01 02:30:23,612 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 54
# [2023-07-01 02:30:23,625 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 55
# [2023-07-01 02:30:23,638 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 56
# [2023-07-01 02:30:23,651 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 57
# [2023-07-01 02:30:23,664 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 58
# [2023-07-01 02:30:23,677 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 59
# [2023-07-01 02:30:23,689 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 60
# [2023-07-01 02:30:23,703 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 61
# [2023-07-01 02:30:23,717 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 62
# [2023-07-01 02:30:23,729 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 63
# [2023-07-01 02:30:23,742 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 64
# [2023-07-01 02:30:23,928 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 65
# [2023-07-01 02:30:23,941 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 66
# [2023-07-01 02:30:23,954 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 67
# [2023-07-01 02:30:23,967 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 68
# [2023-07-01 02:30:23,982 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 69
# [2023-07-01 02:30:23,996 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 70
# [2023-07-01 02:30:24,010 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 71
# [2023-07-01 02:30:24,023 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 72
# [2023-07-01 02:30:24,035 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 73
# [2023-07-01 02:30:24,048 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 74
# [2023-07-01 02:30:24,061 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 75
# [2023-07-01 02:30:24,075 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 76
# [2023-07-01 02:30:24,087 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 77
# [2023-07-01 02:30:24,100 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 78
# [2023-07-01 02:30:24,113 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 79
# [2023-07-01 02:30:24,126 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 80
# [2023-07-01 02:30:24,138 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 81
# [2023-07-01 02:30:24,153 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 82
# [2023-07-01 02:30:24,167 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 83
# [2023-07-01 02:30:24,180 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 84
# [2023-07-01 02:30:24,194 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 85
# [2023-07-01 02:30:24,208 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 86
# [2023-07-01 02:30:24,431 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 87
# [2023-07-01 02:30:24,444 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 88
# [2023-07-01 02:30:24,457 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 89
# [2023-07-01 02:30:24,470 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 90
# [2023-07-01 02:30:24,483 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 91
# [2023-07-01 02:30:24,496 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 92
# [2023-07-01 02:30:24,509 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 93
# [2023-07-01 02:30:24,521 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 94
# [2023-07-01 02:30:24,534 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 95
# [2023-07-01 02:30:24,547 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 96
# [2023-07-01 02:30:24,559 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 97
# [2023-07-01 02:30:24,573 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 98
# [2023-07-01 02:30:24,586 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 99
# [2023-07-01 02:30:24,600 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 100
# [2023-07-01 02:30:24,613 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 101
# [2023-07-01 02:30:24,628 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 102
# [2023-07-01 02:30:24,642 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 103
# [2023-07-01 02:30:24,655 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 104
# [2023-07-01 02:30:24,669 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 105
# [2023-07-01 02:30:24,683 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 106
# [2023-07-01 02:30:24,696 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 107
# [2023-07-01 02:30:24,710 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 108
# [2023-07-01 02:30:24,723 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 109
# [2023-07-01 02:30:24,736 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 110
# [2023-07-01 02:30:24,749 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 111
# [2023-07-01 02:30:24,762 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 112
# [2023-07-01 02:30:24,775 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 113
# [2023-07-01 02:30:25,043 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 114
# [2023-07-01 02:30:25,056 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 115
# [2023-07-01 02:30:25,069 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 116
# [2023-07-01 02:30:25,082 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 117
# [2023-07-01 02:30:25,096 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 118
# [2023-07-01 02:30:25,109 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 119
# [2023-07-01 02:30:25,122 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 120
# [2023-07-01 02:30:25,134 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 121
# [2023-07-01 02:30:25,148 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 122
# [2023-07-01 02:30:25,162 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 123
# [2023-07-01 02:30:25,175 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 124
# [2023-07-01 02:30:25,188 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 125
# [2023-07-01 02:30:25,202 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 126
# [2023-07-01 02:30:25,216 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 127
# [2023-07-01 02:30:25,231 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 128
# [2023-07-01 02:30:25,245 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 129
# [2023-07-01 02:30:25,260 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 130
# [2023-07-01 02:30:25,275 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 131
# [2023-07-01 02:30:25,289 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 132
# [2023-07-01 02:30:25,303 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 133
# [2023-07-01 02:30:25,317 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 134
# [2023-07-01 02:30:25,329 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 135
# [2023-07-01 02:30:25,342 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 136
# [2023-07-01 02:30:25,355 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 137
# [2023-07-01 02:30:25,368 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 138
# [2023-07-01 02:30:25,380 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 139
# [2023-07-01 02:30:25,393 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 140
# [2023-07-01 02:30:25,407 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 141
# [2023-07-01 02:30:25,420 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 142
# [2023-07-01 02:30:25,432 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 143
# [2023-07-01 02:30:25,447 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 144
# [2023-07-01 02:30:25,460 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 145
# [2023-07-01 02:30:25,473 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 146
# [2023-07-01 02:30:25,803 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 147
# [2023-07-01 02:30:25,817 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 148
# [2023-07-01 02:30:25,829 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 149
# [2023-07-01 02:30:25,842 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 150
# [2023-07-01 02:30:25,854 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 151
# [2023-07-01 02:30:25,868 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 152
# [2023-07-01 02:30:25,879 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 153
# [2023-07-01 02:30:25,892 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 154
# [2023-07-01 02:30:25,906 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 155
# [2023-07-01 02:30:25,919 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 156
# [2023-07-01 02:30:25,932 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 157
# [2023-07-01 02:30:25,944 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 158
# [2023-07-01 02:30:25,958 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 159
# [2023-07-01 02:30:25,972 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 160
# [2023-07-01 02:30:25,986 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 161
# [2023-07-01 02:30:25,999 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 162
# [2023-07-01 02:30:26,012 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 163
# [2023-07-01 02:30:26,025 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 164
# [2023-07-01 02:30:26,039 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 165
# [2023-07-01 02:30:26,055 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 166
# [2023-07-01 02:30:26,070 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 167
# [2023-07-01 02:30:26,085 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 168
# [2023-07-01 02:30:26,100 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 169
# [2023-07-01 02:30:26,115 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 170
# [2023-07-01 02:30:26,130 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 171
# [2023-07-01 02:30:26,144 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 172
# [2023-07-01 02:30:26,159 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 173
# [2023-07-01 02:30:26,173 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 174
# [2023-07-01 02:30:26,188 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 175
# [2023-07-01 02:30:26,202 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 176
# [2023-07-01 02:30:26,215 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 177
# [2023-07-01 02:30:26,229 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 178
# [2023-07-01 02:30:26,242 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 179
# [2023-07-01 02:30:26,256 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 180
# [2023-07-01 02:30:26,271 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 181
# [2023-07-01 02:30:26,286 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 182
# [2023-07-01 02:30:26,300 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 183
# [2023-07-01 02:30:26,313 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 184
# [2023-07-01 02:30:26,327 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 185
# [2023-07-01 02:30:26,340 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 186
# [2023-07-01 02:30:26,353 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 187
# [2023-07-01 02:30:26,366 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 188
# [2023-07-01 02:30:26,784 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 189
# [2023-07-01 02:30:26,798 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 190
# [2023-07-01 02:30:26,811 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 191
# [2023-07-01 02:30:26,823 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 192
# [2023-07-01 02:30:26,836 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 193
# [2023-07-01 02:30:26,849 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 194
# [2023-07-01 02:30:26,862 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 195
# [2023-07-01 02:30:26,876 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 196
# [2023-07-01 02:30:26,889 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 197
# [2023-07-01 02:30:26,901 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 198
# [2023-07-01 02:30:26,914 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 199
# [2023-07-01 02:30:26,927 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 200
# [2023-07-01 02:30:26,940 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 201
# [2023-07-01 02:30:53,781 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=201)
#
# [2023-07-01 02:30:53,781 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 202
# [2023-07-01 02:30:53,796 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 203
# [2023-07-01 02:30:53,813 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 204
# [2023-07-01 02:30:53,829 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 205
# [2023-07-01 02:30:53,845 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 206
# [2023-07-01 02:30:53,860 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 207
# [2023-07-01 02:30:53,876 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 208
# [2023-07-01 02:30:53,892 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 209
# [2023-07-01 02:30:53,908 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 210
# [2023-07-01 02:30:53,922 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 211
# [2023-07-01 02:30:53,936 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 212
# [2023-07-01 02:30:53,951 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 213
# [2023-07-01 02:30:53,965 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 214
# [2023-07-01 02:30:53,980 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 215
# [2023-07-01 02:30:53,996 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 216
# [2023-07-01 02:30:54,009 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 217
# [2023-07-01 02:30:54,023 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 218
# [2023-07-01 02:30:54,037 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 219
# [2023-07-01 02:30:54,052 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 220
# [2023-07-01 02:30:54,067 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 221
# [2023-07-01 02:30:54,082 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 222
# [2023-07-01 02:30:54,097 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 223
# [2023-07-01 02:30:54,111 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 224
# [2023-07-01 02:30:54,126 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 225
# [2023-07-01 02:30:54,140 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 226
# [2023-07-01 02:30:54,155 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 227
# [2023-07-01 02:30:54,171 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 228
# [2023-07-01 02:30:54,188 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 229
# [2023-07-01 02:30:54,202 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 230
# [2023-07-01 02:30:54,216 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 231
# [2023-07-01 02:30:54,228 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 232
# [2023-07-01 02:30:55,613 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 233
# [2023-07-01 02:30:55,626 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 234
# [2023-07-01 02:30:55,639 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 235
# [2023-07-01 02:30:55,652 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 236
# [2023-07-01 02:30:55,664 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 237
# [2023-07-01 02:30:55,676 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 238
# [2023-07-01 02:30:55,688 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 239
# [2023-07-01 02:30:55,701 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 240
# [2023-07-01 02:30:55,713 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 241
# [2023-07-01 02:30:55,727 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 242
# [2023-07-01 02:30:55,740 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 243
# [2023-07-01 02:30:55,753 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 244
# [2023-07-01 02:30:55,766 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 245
# [2023-07-01 02:30:55,778 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 246
# [2023-07-01 02:30:55,790 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 247
# [2023-07-01 02:30:55,804 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 248
# [2023-07-01 02:30:55,817 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 249
# [2023-07-01 02:30:55,830 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 250
# [2023-07-01 02:30:55,843 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 251
# [2023-07-01 02:30:55,855 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 252
# [2023-07-01 02:30:55,868 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 253
# [2023-07-01 02:30:55,881 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 254
# [2023-07-01 02:30:55,895 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 255
# [2023-07-01 02:30:55,909 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 256
# [2023-07-01 02:30:55,922 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 257
# [2023-07-01 02:30:55,935 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 258
# [2023-07-01 02:30:55,948 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 259
# [2023-07-01 02:30:55,962 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 260
# [2023-07-01 02:30:55,973 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 261
# [2023-07-01 02:30:55,987 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 262
# [2023-07-01 02:30:56,000 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 263
# [2023-07-01 02:30:56,013 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 264
# [2023-07-01 02:30:56,027 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 265
# [2023-07-01 02:30:56,042 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 266
# [2023-07-01 02:30:56,055 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 267
# [2023-07-01 02:30:56,070 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 268
# [2023-07-01 02:30:56,084 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 269
# [2023-07-01 02:30:56,099 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 270
# [2023-07-01 02:30:56,111 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 271
# [2023-07-01 02:30:56,125 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 272
# [2023-07-01 02:30:56,138 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 273
# [2023-07-01 02:30:56,152 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 274
# [2023-07-01 02:30:56,165 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 275
# [2023-07-01 02:30:56,179 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 276
# [2023-07-01 02:30:56,192 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 277
# [2023-07-01 02:30:56,205 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 278
# [2023-07-01 02:30:56,219 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 279
# [2023-07-01 02:30:56,232 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 280
# [2023-07-01 02:30:56,245 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 281
# [2023-07-01 02:30:56,259 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 282
# [2023-07-01 02:30:56,271 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 283
# [2023-07-01 02:30:56,284 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 284
# [2023-07-01 02:30:56,297 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 285
# [2023-07-01 02:30:56,311 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 286
# [2023-07-01 02:30:56,325 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 287
# [2023-07-01 02:30:56,338 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 288
# [2023-07-01 02:30:56,351 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 289
# [2023-07-01 02:30:56,364 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 290
# [2023-07-01 02:30:56,378 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 291
# [2023-07-01 02:30:56,389 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 292
# [2023-07-01 02:30:56,402 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 293
# [2023-07-01 02:30:56,415 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 294
# [2023-07-01 02:30:56,428 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 295
# [2023-07-01 02:30:56,441 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 296
# [2023-07-01 02:30:56,454 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 297
# [2023-07-01 02:30:56,466 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 298
# [2023-07-01 02:30:56,479 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 299
# [2023-07-01 02:30:56,491 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 300
# [2023-07-01 02:30:56,504 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 301
# [2023-07-01 02:30:56,517 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 302
# [2023-07-01 02:30:56,529 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 303
# [2023-07-01 02:30:58,190 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 304
# [2023-07-01 02:30:58,204 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 305
# [2023-07-01 02:30:58,215 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 306
# [2023-07-01 02:30:58,228 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 307
# [2023-07-01 02:30:58,241 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 308
# [2023-07-01 02:30:58,254 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 309
# [2023-07-01 02:30:58,267 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 310
# [2023-07-01 02:30:58,281 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 311
# [2023-07-01 02:30:58,295 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 312
# [2023-07-01 02:30:58,309 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 313
# [2023-07-01 02:30:58,323 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 314
# [2023-07-01 02:30:58,336 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 315
# [2023-07-01 02:30:58,349 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 316
# [2023-07-01 02:30:58,363 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 317
# [2023-07-01 02:30:58,375 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 318
# [2023-07-01 02:30:58,388 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 319
# [2023-07-01 02:30:58,401 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 320
# [2023-07-01 02:30:58,413 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 321
# [2023-07-01 02:30:58,426 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 322
# [2023-07-01 02:30:58,439 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 323
# [2023-07-01 02:30:58,452 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 324
# [2023-07-01 02:30:58,467 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 325
# [2023-07-01 02:30:58,482 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 326
# [2023-07-01 02:30:58,496 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 327
# [2023-07-01 02:30:58,510 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 328
# [2023-07-01 02:30:58,524 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 329
# [2023-07-01 02:30:58,538 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 330
# [2023-07-01 02:30:58,553 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 331
# [2023-07-01 02:30:58,567 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 332
# [2023-07-01 02:30:58,580 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 333
# [2023-07-01 02:30:58,593 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 334
# [2023-07-01 02:30:58,606 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 335
# [2023-07-01 02:30:58,619 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 336
# [2023-07-01 02:30:58,634 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 337
# [2023-07-01 02:30:58,648 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 338
# [2023-07-01 02:30:58,661 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 339
# [2023-07-01 02:30:58,674 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 340
# [2023-07-01 02:30:58,687 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 341
# [2023-07-01 02:30:58,701 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 342
# [2023-07-01 02:30:58,715 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 343
# [2023-07-01 02:30:58,728 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 344
# [2023-07-01 02:30:58,742 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 345
# [2023-07-01 02:30:58,754 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 346
# [2023-07-01 02:30:58,767 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 347
# [2023-07-01 02:30:58,780 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 348
# [2023-07-01 02:30:58,792 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 349
# [2023-07-01 02:30:58,805 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 350
# [2023-07-01 02:30:58,817 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 351
# [2023-07-01 02:30:58,830 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 352
# [2023-07-01 02:30:58,843 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 353
# [2023-07-01 02:30:58,856 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 354
# [2023-07-01 02:30:58,870 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 355
# [2023-07-01 02:30:58,883 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 356
# [2023-07-01 02:30:58,895 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 357
# [2023-07-01 02:30:58,909 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 358
# [2023-07-01 02:30:58,922 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 359
# [2023-07-01 02:30:58,935 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 360
# [2023-07-01 02:30:58,950 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 361
# [2023-07-01 02:30:58,963 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 362
# [2023-07-01 02:30:58,977 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 363
# [2023-07-01 02:30:58,990 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 364
# [2023-07-01 02:30:59,003 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 365
# [2023-07-01 02:30:59,015 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 366
# [2023-07-01 02:30:59,028 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 367
# [2023-07-01 02:30:59,042 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 368
# [2023-07-01 02:30:59,057 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 369
# [2023-07-01 02:30:59,072 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 370
# [2023-07-01 02:30:59,087 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 371
# [2023-07-01 02:30:59,101 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 372
# [2023-07-01 02:30:59,115 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 373
# [2023-07-01 02:30:59,130 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 374
# [2023-07-01 02:30:59,144 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 375
# [2023-07-01 02:30:59,158 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 376
# [2023-07-01 02:30:59,172 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 377
# [2023-07-01 02:30:59,186 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 378
# [2023-07-01 02:30:59,201 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 379
# [2023-07-01 02:30:59,214 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 380
# [2023-07-01 02:30:59,228 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 381
# [2023-07-01 02:30:59,241 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 382
# [2023-07-01 02:30:59,256 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 383
# [2023-07-01 02:30:59,269 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 384
# [2023-07-01 02:30:59,283 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 385
# [2023-07-01 02:30:59,297 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 386
# [2023-07-01 02:30:59,311 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 387
# [2023-07-01 02:30:59,324 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 388
# [2023-07-01 02:30:59,338 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 389
# [2023-07-01 02:30:59,351 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 390
# [2023-07-01 02:30:59,364 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 391
# [2023-07-01 02:30:59,377 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 392
# [2023-07-01 02:31:01,198 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 393
# [2023-07-01 02:31:01,211 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 394
# [2023-07-01 02:31:01,223 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 395
# [2023-07-01 02:31:01,235 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 396
# [2023-07-01 02:31:01,248 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 397
# [2023-07-01 02:31:01,261 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 398
# [2023-07-01 02:31:01,274 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 399
# [2023-07-01 02:31:01,286 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 400
# [2023-07-01 02:31:01,300 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 401
# [2023-07-01 02:31:17,988 INFO] Step 100/ 3000; acc: 72.8; ppl:   7.6; xent: 2.0; lr: 0.00028; sents:  163048; bsz: 3222/3668/408; 23224/26436 tok/s;     55 sec;
# [2023-07-01 02:31:28,296 INFO] * Transform statistics for corpus_1(100.00%):
# 			* FilterTooLongStats(filtered=200)
#
# [2023-07-01 02:31:28,297 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 402
# [2023-07-01 02:31:28,330 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 403
# [2023-07-01 02:31:28,345 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 404
# [2023-07-01 02:31:28,360 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 405
# [2023-07-01 02:31:28,375 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 406
# [2023-07-01 02:31:28,390 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 407
# [2023-07-01 02:31:28,403 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 408
# [2023-07-01 02:31:28,418 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 409
# [2023-07-01 02:31:28,433 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 410
# [2023-07-01 02:31:28,447 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 411
# [2023-07-01 02:31:28,462 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 412
# [2023-07-01 02:31:28,478 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 413
# [2023-07-01 02:31:28,492 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 414
# [2023-07-01 02:31:28,507 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 415
# [2023-07-01 02:31:28,522 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 416
# [2023-07-01 02:31:28,538 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 417
# [2023-07-01 02:31:28,554 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 418
# [2023-07-01 02:31:28,569 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 419
# [2023-07-01 02:31:28,584 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 420
# [2023-07-01 02:31:28,599 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 421
# [2023-07-01 02:31:28,614 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 422
# [2023-07-01 02:31:28,629 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 423
# [2023-07-01 02:31:28,644 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 424
# [2023-07-01 02:31:28,658 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 425
# [2023-07-01 02:31:28,673 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 426
# [2023-07-01 02:31:28,686 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 427
# [2023-07-01 02:31:28,698 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 428
# [2023-07-01 02:31:28,709 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 429
# [2023-07-01 02:31:28,722 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 430
# [2023-07-01 02:31:28,735 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 431
# [2023-07-01 02:31:28,748 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 432
# [2023-07-01 02:31:28,761 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 433
# [2023-07-01 02:31:28,773 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 434
# [2023-07-01 02:31:28,787 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 435
# [2023-07-01 02:31:28,800 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 436
# [2023-07-01 02:31:28,812 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 437
# [2023-07-01 02:31:28,824 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 438
# [2023-07-01 02:31:28,837 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 439
# [2023-07-01 02:31:28,850 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 440
# [2023-07-01 02:31:28,862 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 441
# [2023-07-01 02:31:28,875 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 442
# [2023-07-01 02:31:28,888 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 443
# [2023-07-01 02:31:28,899 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 444
# [2023-07-01 02:31:28,911 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 445
# [2023-07-01 02:31:28,923 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 446
# [2023-07-01 02:31:28,936 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 447
# [2023-07-01 02:31:28,948 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 448
# [2023-07-01 02:31:28,960 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 449
# [2023-07-01 02:31:28,972 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 450
# [2023-07-01 02:31:28,984 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 451
# [2023-07-01 02:31:28,996 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 452
# [2023-07-01 02:31:29,008 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 453
# [2023-07-01 02:31:29,022 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 454
# [2023-07-01 02:31:30,571 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 455
# [2023-07-01 02:31:30,584 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 456
# [2023-07-01 02:31:30,597 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 457
# [2023-07-01 02:31:30,608 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 458
# [2023-07-01 02:31:30,620 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 459
# [2023-07-01 02:31:30,633 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 460
# [2023-07-01 02:31:30,645 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 461
# [2023-07-01 02:31:30,657 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 462
# [2023-07-01 02:31:30,669 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 463
# [2023-07-01 02:31:30,682 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 464
# [2023-07-01 02:31:30,694 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 465
# [2023-07-01 02:31:30,707 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 466
# [2023-07-01 02:31:30,720 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 467
# [2023-07-01 02:31:30,732 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 468
# [2023-07-01 02:31:30,745 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 469
# [2023-07-01 02:31:30,757 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 470
# [2023-07-01 02:31:30,770 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 471
# [2023-07-01 02:31:30,783 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 472
# [2023-07-01 02:31:30,794 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 473
# [2023-07-01 02:31:30,807 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 474
# [2023-07-01 02:31:30,819 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 475
# [2023-07-01 02:31:30,834 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 476
# [2023-07-01 02:31:30,847 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 477
# [2023-07-01 02:31:30,861 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 478
# [2023-07-01 02:31:30,875 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 479
# [2023-07-01 02:31:30,887 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 480
# [2023-07-01 02:31:30,901 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 481
# [2023-07-01 02:31:30,915 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 482
# [2023-07-01 02:31:30,929 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 483
# [2023-07-01 02:31:30,942 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 484
# [2023-07-01 02:31:30,956 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 485
# [2023-07-01 02:31:30,968 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 486
# [2023-07-01 02:31:30,982 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 487
# [2023-07-01 02:31:30,995 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 488
# [2023-07-01 02:31:31,006 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 489
# [2023-07-01 02:31:31,019 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 490
# [2023-07-01 02:31:31,031 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 491
# [2023-07-01 02:31:31,043 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 492
# [2023-07-01 02:31:31,059 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 493
# [2023-07-01 02:31:31,077 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 494
# [2023-07-01 02:31:31,091 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 495
# [2023-07-01 02:31:31,104 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 496
# [2023-07-01 02:31:31,117 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 497
# [2023-07-01 02:31:31,130 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 498
# [2023-07-01 02:31:31,142 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 499
# [2023-07-01 02:31:31,155 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 500
# [2023-07-01 02:31:31,167 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 501
# [2023-07-01 02:31:31,180 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 502
# [2023-07-01 02:31:31,194 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 503
# [2023-07-01 02:31:31,205 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 504
# [2023-07-01 02:31:31,217 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 505
# [2023-07-01 02:31:31,230 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 506
# [2023-07-01 02:31:31,242 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 507
# [2023-07-01 02:31:31,254 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 508
# [2023-07-01 02:31:31,267 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 509
# [2023-07-01 02:31:31,279 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 510
# [2023-07-01 02:31:31,292 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 511
# [2023-07-01 02:31:31,304 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 512
# [2023-07-01 02:31:31,319 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 513
# [2023-07-01 02:31:31,331 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 514
# [2023-07-01 02:31:31,343 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 515
# [2023-07-01 02:31:31,355 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 516
# [2023-07-01 02:31:31,367 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 517
# [2023-07-01 02:31:31,380 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 518
# [2023-07-01 02:31:31,391 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 519
# [2023-07-01 02:31:31,403 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 520
# [2023-07-01 02:31:31,416 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 521
# ...
# 			* corpus_1: 9037
# [2023-07-01 02:57:32,370 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9038
# [2023-07-01 02:57:32,383 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9039
# [2023-07-01 02:57:32,396 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9040
# [2023-07-01 02:57:32,410 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9041
# [2023-07-01 02:57:32,422 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9042
# [2023-07-01 02:57:32,435 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9043
# [2023-07-01 02:57:32,449 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9044
# [2023-07-01 02:57:32,462 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9045
# [2023-07-01 02:57:32,475 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9046
# [2023-07-01 02:57:32,488 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9047
# [2023-07-01 02:57:32,501 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9048
# [2023-07-01 02:57:32,514 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9049
# [2023-07-01 02:57:32,525 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9050
# [2023-07-01 02:57:32,538 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9051
# [2023-07-01 02:57:32,551 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9052
# [2023-07-01 02:57:32,565 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9053
# [2023-07-01 02:57:32,578 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9054
# [2023-07-01 02:57:34,235 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9055
# [2023-07-01 02:57:34,249 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9056
# [2023-07-01 02:57:34,261 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9057
# [2023-07-01 02:57:34,274 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9058
# [2023-07-01 02:57:34,287 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9059
# [2023-07-01 02:57:34,300 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9060
# [2023-07-01 02:57:34,313 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9061
# [2023-07-01 02:57:34,325 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9062
# [2023-07-01 02:57:34,338 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9063
# [2023-07-01 02:57:34,350 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9064
# [2023-07-01 02:57:34,364 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9065
# [2023-07-01 02:57:34,378 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9066
# [2023-07-01 02:57:34,392 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9067
# [2023-07-01 02:57:34,405 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9068
# [2023-07-01 02:57:34,419 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9069
# [2023-07-01 02:57:34,431 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9070
# [2023-07-01 02:57:34,445 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9071
# [2023-07-01 02:57:34,458 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9072
# [2023-07-01 02:57:34,470 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9073
# [2023-07-01 02:57:34,483 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9074
# [2023-07-01 02:57:34,496 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9075
# [2023-07-01 02:57:34,509 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9076
# [2023-07-01 02:57:34,521 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9077
# [2023-07-01 02:57:34,534 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9078
# [2023-07-01 02:57:34,546 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9079
# [2023-07-01 02:57:34,559 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9080
# [2023-07-01 02:57:34,572 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9081
# [2023-07-01 02:57:34,584 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9082
# [2023-07-01 02:57:34,597 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9083
# [2023-07-01 02:57:34,610 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9084
# [2023-07-01 02:57:34,623 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9085
# [2023-07-01 02:57:34,635 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9086
# [2023-07-01 02:57:34,649 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9087
# [2023-07-01 02:57:34,662 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9088
# [2023-07-01 02:57:34,674 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9089
# [2023-07-01 02:57:34,687 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9090
# [2023-07-01 02:57:34,700 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9091
# [2023-07-01 02:57:34,713 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9092
# [2023-07-01 02:57:34,727 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9093
# [2023-07-01 02:57:34,738 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9094
# [2023-07-01 02:57:34,751 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9095
# [2023-07-01 02:57:34,764 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9096
# [2023-07-01 02:57:34,777 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9097
# [2023-07-01 02:57:34,789 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9098
# [2023-07-01 02:57:34,803 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9099
# [2023-07-01 02:57:34,816 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9100
# [2023-07-01 02:57:34,829 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9101
# [2023-07-01 02:57:34,842 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9102
# [2023-07-01 02:57:34,856 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9103
# [2023-07-01 02:57:34,869 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9104
# [2023-07-01 02:57:34,881 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9105
# [2023-07-01 02:57:34,894 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9106
# [2023-07-01 02:57:34,908 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9107
# [2023-07-01 02:57:34,922 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9108
# [2023-07-01 02:57:34,933 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9109
# [2023-07-01 02:57:34,945 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9110
# [2023-07-01 02:57:34,959 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9111
# [2023-07-01 02:57:34,972 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9112
# [2023-07-01 02:57:34,984 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9113
# [2023-07-01 02:57:34,997 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9114
# [2023-07-01 02:57:35,010 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9115
# [2023-07-01 02:57:35,023 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9116
# [2023-07-01 02:57:35,036 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9117
# [2023-07-01 02:57:35,049 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9118
# [2023-07-01 02:57:35,062 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9119
# [2023-07-01 02:57:35,076 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9120
# [2023-07-01 02:57:35,088 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9121
# [2023-07-01 02:57:35,101 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9122
# [2023-07-01 02:57:35,114 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9123
# [2023-07-01 02:57:35,127 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9124
# [2023-07-01 02:57:35,138 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9125
# [2023-07-01 02:57:35,151 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9126
# [2023-07-01 02:57:35,164 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9127
# [2023-07-01 02:57:37,102 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9128
# [2023-07-01 02:57:37,115 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9129
# [2023-07-01 02:57:37,129 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9130
# [2023-07-01 02:57:37,142 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9131
# [2023-07-01 02:57:37,156 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9132
# [2023-07-01 02:57:37,170 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9133
# [2023-07-01 02:57:37,184 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9134
# [2023-07-01 02:57:37,197 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9135
# [2023-07-01 02:57:37,210 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9136
# [2023-07-01 02:57:37,224 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9137
# [2023-07-01 02:57:37,239 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9138
# [2023-07-01 02:57:37,250 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9139
# [2023-07-01 02:57:37,264 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9140
# [2023-07-01 02:57:37,279 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9141
# [2023-07-01 02:57:37,294 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9142
# [2023-07-01 02:57:37,308 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9143
# [2023-07-01 02:57:37,322 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9144
# [2023-07-01 02:57:37,337 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9145
# [2023-07-01 02:57:37,350 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9146
# [2023-07-01 02:57:37,363 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9147
# [2023-07-01 02:57:37,378 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9148
# [2023-07-01 02:57:37,392 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9149
# [2023-07-01 02:57:37,405 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9150
# [2023-07-01 02:57:37,419 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9151
# [2023-07-01 02:57:37,432 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9152
# [2023-07-01 02:57:37,446 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9153
# [2023-07-01 02:57:37,458 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9154
# [2023-07-01 02:57:37,471 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9155
# [2023-07-01 02:57:37,485 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9156
# [2023-07-01 02:57:37,499 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9157
# [2023-07-01 02:57:37,512 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9158
# [2023-07-01 02:57:37,526 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9159
# [2023-07-01 02:57:37,539 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9160
# [2023-07-01 02:57:37,552 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9161
# [2023-07-01 02:57:37,565 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9162
# [2023-07-01 02:57:37,579 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9163
# [2023-07-01 02:57:37,593 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9164
# [2023-07-01 02:57:37,607 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9165
# [2023-07-01 02:57:37,620 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9166
# [2023-07-01 02:57:37,632 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9167
# [2023-07-01 02:57:37,645 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9168
# [2023-07-01 02:57:37,658 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9169
# [2023-07-01 02:57:37,671 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9170
# [2023-07-01 02:57:37,683 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9171
# [2023-07-01 02:57:37,697 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9172
# [2023-07-01 02:57:37,711 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9173
# [2023-07-01 02:57:37,724 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9174
# [2023-07-01 02:57:37,737 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9175
# [2023-07-01 02:57:37,750 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9176
# [2023-07-01 02:57:37,763 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9177
# [2023-07-01 02:57:37,775 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9178
# [2023-07-01 02:57:37,788 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9179
# [2023-07-01 02:57:37,802 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9180
# [2023-07-01 02:57:37,814 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9181
# [2023-07-01 02:57:37,827 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9182
# [2023-07-01 02:57:37,840 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9183
# [2023-07-01 02:57:37,853 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9184
# [2023-07-01 02:57:37,867 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9185
# [2023-07-01 02:57:37,882 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9186
# [2023-07-01 02:57:37,897 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9187
# [2023-07-01 02:57:37,911 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9188
# [2023-07-01 02:57:37,925 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9189
# [2023-07-01 02:57:37,940 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9190
# [2023-07-01 02:57:37,954 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9191
# [2023-07-01 02:57:37,968 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9192
# [2023-07-01 02:57:37,983 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9193
# [2023-07-01 02:57:37,997 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9194
# [2023-07-01 02:57:38,012 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9195
# [2023-07-01 02:57:38,027 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9196
# [2023-07-01 02:57:38,042 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9197
# [2023-07-01 02:57:38,057 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9198
# [2023-07-01 02:57:38,071 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9199
# [2023-07-01 02:57:38,084 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9200
# [2023-07-01 02:57:38,098 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9201
# [2023-07-01 02:57:38,112 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9202
# [2023-07-01 02:57:38,125 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9203
# [2023-07-01 02:57:38,139 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9204
# [2023-07-01 02:57:38,152 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9205
# [2023-07-01 02:57:38,165 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9206
# [2023-07-01 02:57:38,179 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9207
# [2023-07-01 02:57:38,194 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9208
# [2023-07-01 02:57:38,208 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9209
# [2023-07-01 02:57:38,221 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9210
# [2023-07-01 02:57:38,233 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9211
# [2023-07-01 02:57:38,245 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9212
# [2023-07-01 02:57:38,257 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9213
# [2023-07-01 02:57:38,269 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9214
# [2023-07-01 02:57:38,280 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9215
# [2023-07-01 02:57:38,292 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9216
# [2023-07-01 02:57:38,304 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9217
# [2023-07-01 02:57:38,316 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9218
# [2023-07-01 02:57:40,579 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9219
# [2023-07-01 02:57:40,591 INFO] Weighted corpora loaded so far:
# 			* corpus_1: 9220
# [2023-07-01 02:57:53,052 INFO] Step 3000/ 3000; acc: 95.1; ppl:   3.1; xent: 1.1; lr: 0.00161; sents:  162769; bsz: 3213/3659/407; 20797/23680 tok/s;   1651 sec;
# [2023-07-01 02:57:53,372 INFO] valid stats calculation and sentences rebuilding
#                            took: 0.3182089328765869 s.
# [2023-07-01 02:57:53,373 INFO] Train perplexity: 3.24707
# [2023-07-01 02:57:53,373 INFO] Train accuracy: 93.232
# [2023-07-01 02:57:53,373 INFO] Sentences processed: 4.88933e+06
# [2023-07-01 02:57:53,373 INFO] Average bsz: 3219/3664/407
# [2023-07-01 02:57:53,373 INFO] Validation perplexity: 10.3158
# [2023-07-01 02:57:53,373 INFO] Validation accuracy: 71.4871
# [2023-07-01 02:57:53,374 INFO] Stalled patience: 3/4
# [2023-07-01 02:57:53,375 INFO] Saving checkpoint models/model.zhen_step_3000.pt

# %% [markdown]
# ### Translation
#
# Translation Options:
#
#     -model - specify the last model checkpoint name; try testing the quality of multiple checkpoints
#     -src - the subworded test dataset, source file
#     -output - give any file name to the new translation output file
#     -gpu - GPU ID, usually 0 if you have one GPU. Otherwise, it will translate on CPU, which would be slower.
#     -min_length - [optional] to avoid empty translations
#     -verbose - [optional] if you want to print translations

# %%
# Translate the "subworded" source file of the test dataset
# Change the model name, if needed.
# !onmt_translate -model models/model.fren_step_3000.pt -src UN.en-fr.fr-filtered.fr.subword.test -output UN.en.translated -gpu 0 -min_length 1
# !onmt_translate -model models/model.zhen_step_3000.pt -src UN.en-zh.zh-filtered.zh.subword.test -output UN.en.translated -gpu 0 -min_length 1
# Out:
# [2023-07-01 03:01:00,753 INFO] Loading checkpoint from models/model.zhen_step_3000.pt
# [2023-07-01 03:01:01,261 INFO] Loading data into the model
# [2023-07-01 03:01:08,655 INFO] PRED SCORE: -0.1701, PRED PPL: 1.19 NB SENTENCES: 1000

# %%
# Check the first 5 lines of the translation file
# !head -n 5 UN.en.translated
# Out:
# ▁RESOLUTION ▁ 6 2 / 2 2 4
# ▁RESOLUTION ▁ 5 5 / 1 7 2
# ▁ 1 7 . ▁Ur ges ▁States :
# ▁RESOLUTION ▁ 6 1 / 1 4 6
# ▁RESOLUTION ▁ 6 2 / 2 2 7

# %%
# If needed install/update sentencepiece
# !pip3 install --upgrade -q sentencepiece

# Desubword the translation file
# !python3 MT-Preparation/subwording/3-desubword.py target.model UN.en.translated
# Out:
# Done desubwording! Output: UN.en.translated.desubword

# %%
# Check the first 5 lines of the desubworded translation file
# !head -n 5 UN.en.translated.desubword
# Out:
# RESOLUTION 62/224
# RESOLUTION 55/172
# 17. Urges States:
# RESOLUTION 61/146
# RESOLUTION 62/227

# %%
# Desubword the target file (reference) of the test dataset
# Note: You might as well have split files *before* subwording during dataset preperation, 
# but sometimes datasets have tokeniztion issues, so this way you are sure the file is really untokenized.
# !python3 MT-Preparation/subwording/3-desubword.py target.model UN.en-zh.en-filtered.en.subword.test
# Out:
# Done desubwording! Output: UN.en-zh.en-filtered.en.subword.test.desubword

# %%
# Check the first 5 lines of the desubworded reference
# !head -n 5 UN.en-zh.en-filtered.en.subword.test.desubword
# Out:
# RESOLUTION 62/224
# RESOLUTION 55/172
# (a) Field Security Operations: 172,417,700 dollars;
# RESOLUTION 61/44
# RESOLUTION 62/67

# %% [markdown]
# ### MT Evaluation
#
# There are several MT Evaluation metrics such as BLEU, TER, METEOR, COMET, BERTScore, among others.
#
# Here we are using BLEU. Files must be detokenized/desubworded beforehand.

# %%
# Download the BLEU script
# !wget https://raw.githubusercontent.com/ymoslem/MT-Evaluation/main/BLEU/compute-bleu.py
# Out:
# --2023-07-01 00:38:27--  https://raw.githubusercontent.com/ymoslem/MT-Evaluation/main/BLEU/compute-bleu.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 957 [text/plain]
# Saving to: ‘compute-bleu.py’
#
# compute-bleu.py     100%[===================>]     957  --.-KB/s    in 0s
#
# 2023-07-01 00:38:29 (19.2 MB/s) - ‘compute-bleu.py’ saved [957/957]

# %%
# Install sacrebleu
# !pip3 install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in /home/venv/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: portalocker in /home/venv/lib/python3.9/site-packages (from sacrebleu) (2.7.0)
# Requirement already satisfied: regex in /home/venv/lib/python3.9/site-packages (from sacrebleu) (2023.6.3)
# Requirement already satisfied: tabulate>=0.8.9 in /home/venv/lib/python3.9/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /home/venv/lib/python3.9/site-packages (from sacrebleu) (1.23.5)
# Requirement already satisfied: colorama in /home/venv/lib/python3.9/site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /home/venv/lib/python3.9/site-packages (from sacrebleu) (4.9.2)

# %%
# Evaluate the translation (without subwording)
# !python3 compute-bleu.py UN.en-zh.en-filtered.en.subword.test.desubword UN.en.translated.desubword
# Out:
# Reference 1st sentence: RESOLUTION 62/224
# MTed 1st sentence: RESOLUTION 62/224
# BLEU:  36.78133901833709
