# %%
import os
os.environ['HTTP_PROXY'] = 'http://proxy.vmware.com:3128'
os.environ['HTTPS_PROXY'] = 'http://proxy.vmware.com:3128'

# %%
# !pip install modelscope==1.4.2
# !pip install open_clip_torch
# !pip install pytorch-lightning
# !pip install opencv-python
# Out:
# Requirement already satisfied: modelscope==1.4.2 in /home/venv/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: addict in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (2.4.0)
# Requirement already satisfied: attrs in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (23.1.0)
# Requirement already satisfied: datasets<=2.8.0,>=2.7.0 in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (2.8.0)
# Requirement already satisfied: einops in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (0.6.1)
# Requirement already satisfied: filelock>=3.3.0 in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (3.12.0)
# Requirement already satisfied: gast>=0.2.2 in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (0.4.0)
# Requirement already satisfied: jsonplus in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (0.8.0)
# Requirement already satisfied: numpy<1.24.0 in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (1.23.5)
# Requirement already satisfied: oss2 in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (2.18.0)
# Requirement already satisfied: Pillow>=6.2.0 in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (9.3.0)
# Requirement already satisfied: pyarrow!=9.0.0,>=6.0.0 in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (12.0.0)
# Requirement already satisfied: pyyaml in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (6.0)
# Requirement already satisfied: requests in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (2.30.0)
# Requirement already satisfied: scipy in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (1.10.1)
# Requirement already satisfied: setuptools in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (67.7.2)
# Requirement already satisfied: tqdm>=4.64.0 in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (4.65.0)
# Requirement already satisfied: yapf in /home/venv/lib/python3.9/site-packages (from modelscope==1.4.2) (0.40.1)
# Requirement already satisfied: dill<0.3.7 in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (0.3.6)
# Requirement already satisfied: pandas in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (2.0.1)
# Requirement already satisfied: xxhash in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (3.2.0)
# Requirement already satisfied: multiprocess in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (0.15.1)
# Requirement already satisfied: packaging in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (23.1)
# Requirement already satisfied: responses<0.19 in /home/venv/lib/python3.9/site-packages (from datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/venv/lib/python3.9/site-packages (from requests->modelscope==1.4.2) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/venv/lib/python3.9/site-packages (from requests->modelscope==1.4.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/venv/lib/python3.9/site-packages (from requests->modelscope==1.4.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/venv/lib/python3.9/site-packages (from requests->modelscope==1.4.2) (2023.5.7)
# Requirement already satisfied: simplejson>=3.3.0 in /home/venv/lib/python3.9/site-packages (from jsonplus->modelscope==1.4.2) (3.19.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/venv/lib/python3.9/site-packages (from jsonplus->modelscope==1.4.2) (2.8.2)
# Requirement already satisfied: sortedcontainers>=1.5.9 in /home/venv/lib/python3.9/site-packages (from jsonplus->modelscope==1.4.2) (2.4.0)
# Requirement already satisfied: crcmod>=1.7 in /home/venv/lib/python3.9/site-packages (from oss2->modelscope==1.4.2) (1.7)
# Requirement already satisfied: pycryptodome>=3.4.7 in /home/venv/lib/python3.9/site-packages (from oss2->modelscope==1.4.2) (3.18.0)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /home/venv/lib/python3.9/site-packages (from oss2->modelscope==1.4.2) (2.16.1)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /home/venv/lib/python3.9/site-packages (from oss2->modelscope==1.4.2) (2.13.36)
# Requirement already satisfied: six in /home/venv/lib/python3.9/site-packages (from oss2->modelscope==1.4.2) (1.16.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/venv/lib/python3.9/site-packages (from yapf->modelscope==1.4.2) (6.6.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/venv/lib/python3.9/site-packages (from yapf->modelscope==1.4.2) (3.5.3)
# Requirement already satisfied: tomli>=2.0.1 in /home/venv/lib/python3.9/site-packages (from yapf->modelscope==1.4.2) (2.0.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /home/venv/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope==1.4.2) (0.10.0)
# Requirement already satisfied: cryptography>=2.6.0 in /home/venv/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope==1.4.2) (41.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/venv/lib/python3.9/site-packages (from aiohttp->datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/venv/lib/python3.9/site-packages (from aiohttp->datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/venv/lib/python3.9/site-packages (from aiohttp->datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/venv/lib/python3.9/site-packages (from aiohttp->datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/venv/lib/python3.9/site-packages (from aiohttp->datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/venv/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (4.5.0)
# Requirement already satisfied: zipp>=0.5 in /home/venv/lib/python3.9/site-packages (from importlib-metadata>=6.6.0->yapf->modelscope==1.4.2) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /home/venv/lib/python3.9/site-packages (from pandas->datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/venv/lib/python3.9/site-packages (from pandas->datasets<=2.8.0,>=2.7.0->modelscope==1.4.2) (2023.3)
# Requirement already satisfied: cffi>=1.12 in /home/venv/lib/python3.9/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2->modelscope==1.4.2) (1.15.1)
# Requirement already satisfied: pycparser in /home/venv/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2->modelscope==1.4.2) (2.21)
# Requirement already satisfied: open_clip_torch in /home/venv/lib/python3.9/site-packages (2.20.0)
# Requirement already satisfied: torch>=1.9.0 in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (2.0.0+cu117)
# Requirement already satisfied: torchvision in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (0.15.1+cu117)
# Requirement already satisfied: regex in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (2023.6.3)
# Requirement already satisfied: ftfy in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (6.1.1)
# Requirement already satisfied: tqdm in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (4.65.0)
# Requirement already satisfied: huggingface-hub in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (0.15.1)
# Requirement already satisfied: sentencepiece in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (0.1.99)
# Requirement already satisfied: protobuf<4 in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (3.20.3)
# Requirement already satisfied: timm in /home/venv/lib/python3.9/site-packages (from open_clip_torch) (0.9.2)
# Requirement already satisfied: filelock in /home/venv/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/venv/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (4.5.0)
# Requirement already satisfied: sympy in /home/venv/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (1.12)
# Requirement already satisfied: networkx in /home/venv/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (3.1)
# Requirement already satisfied: jinja2 in /home/venv/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /home/venv/lib/python3.9/site-packages (from torch>=1.9.0->open_clip_torch) (2.0.0)
# Requirement already satisfied: cmake in /home/venv/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.9.0->open_clip_torch) (3.26.3)
# Requirement already satisfied: lit in /home/venv/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.9.0->open_clip_torch) (16.0.3)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/venv/lib/python3.9/site-packages (from ftfy->open_clip_torch) (0.2.6)
# Requirement already satisfied: fsspec in /home/venv/lib/python3.9/site-packages (from huggingface-hub->open_clip_torch) (2023.6.0)
# Requirement already satisfied: requests in /home/venv/lib/python3.9/site-packages (from huggingface-hub->open_clip_torch) (2.30.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/venv/lib/python3.9/site-packages (from huggingface-hub->open_clip_torch) (6.0)
# Requirement already satisfied: packaging>=20.9 in /home/venv/lib/python3.9/site-packages (from huggingface-hub->open_clip_torch) (23.1)
# Requirement already satisfied: safetensors in /home/venv/lib/python3.9/site-packages (from timm->open_clip_torch) (0.3.1)
# Requirement already satisfied: numpy in /home/venv/lib/python3.9/site-packages (from torchvision->open_clip_torch) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/venv/lib/python3.9/site-packages (from torchvision->open_clip_torch) (9.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/venv/lib/python3.9/site-packages (from jinja2->torch>=1.9.0->open_clip_torch) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/venv/lib/python3.9/site-packages (from requests->huggingface-hub->open_clip_torch) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/venv/lib/python3.9/site-packages (from requests->huggingface-hub->open_clip_torch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/venv/lib/python3.9/site-packages (from requests->huggingface-hub->open_clip_torch) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/venv/lib/python3.9/site-packages (from requests->huggingface-hub->open_clip_torch) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /home/venv/lib/python3.9/site-packages (from sympy->torch>=1.9.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: pytorch-lightning in /home/venv/lib/python3.9/site-packages (2.0.4)
# Requirement already satisfied: numpy>=1.17.2 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (1.23.5)
# Requirement already satisfied: torch>=1.11.0 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (2.0.0+cu117)
# Requirement already satisfied: tqdm>=4.57.0 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (1.0.0)
# Requirement already satisfied: packaging>=17.1 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /home/venv/lib/python3.9/site-packages (from pytorch-lightning) (0.9.0)
# Requirement already satisfied: requests in /home/venv/lib/python3.9/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.30.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/venv/lib/python3.9/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.4)
# Requirement already satisfied: filelock in /home/venv/lib/python3.9/site-packages (from torch>=1.11.0->pytorch-lightning) (3.12.0)
# Requirement already satisfied: sympy in /home/venv/lib/python3.9/site-packages (from torch>=1.11.0->pytorch-lightning) (1.12)
# Requirement already satisfied: networkx in /home/venv/lib/python3.9/site-packages (from torch>=1.11.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in /home/venv/lib/python3.9/site-packages (from torch>=1.11.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /home/venv/lib/python3.9/site-packages (from torch>=1.11.0->pytorch-lightning) (2.0.0)
# Requirement already satisfied: cmake in /home/venv/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (3.26.3)
# Requirement already satisfied: lit in /home/venv/lib/python3.9/site-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (16.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/venv/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->pytorch-lightning) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/venv/lib/python3.9/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/venv/lib/python3.9/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/venv/lib/python3.9/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /home/venv/lib/python3.9/site-packages (from sympy->torch>=1.11.0->pytorch-lightning) (1.3.0)
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 10.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.17.0 in /home/venv/lib/python3.9/site-packages (from opencv-python) (1.23.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.0.74

# %%
from huggingface_hub import snapshot_download

from modelscope.pipelines import pipeline
from modelscope.outputs import OutputKeys
import pathlib

model_dir = pathlib.Path('weights')
snapshot_download('damo-vilab/modelscope-damo-text-to-video-synthesis',
                   repo_type='model', local_dir=model_dir)

pipe = pipeline('text-to-video-synthesis', model_dir.as_posix())
test_text = {
        'text': 'A panda eating bamboo on a rock.',
    }
output_video_path = pipe(test_text,)[OutputKeys.OUTPUT_VIDEO]
print('output_video_path:', output_video_path)
# Out:
# Fetching 6 files: 100%|██████████| 6/6 [00:01<00:00,  5.88it/s]
# 2023-07-08 08:20:45,307 - modelscope - INFO - initiate model from weights
# 2023-07-08 08:20:45,309 - modelscope - INFO - initiate model from location weights.
# 2023-07-08 08:20:45,312 - modelscope - INFO - initialize model from weights
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2023-07-08 08:22:28,121 - modelscope - WARNING - No preprocessor field found in cfg.
# WARNING:modelscope:No preprocessor field found in cfg.
# 2023-07-08 08:22:28,124 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# WARNING:modelscope:No val key and type key found in preprocessor domain of configuration.json file.
# 2023-07-08 08:22:28,125 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': 'weights'}. trying to build by task and model information.
# WARNING:modelscope:Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': 'weights'}. trying to build by task and model information.
# 2023-07-08 08:22:28,126 - modelscope - WARNING - No preprocessor key ('latent-text-to-video-synthesis', 'text-to-video-synthesis') found in PREPROCESSOR_MAP, skip building preprocessor.
# WARNING:modelscope:No preprocessor key ('latent-text-to-video-synthesis', 'text-to-video-synthesis') found in PREPROCESSOR_MAP, skip building preprocessor.
# 2023-07-08 08:22:28,131 - modelscope - WARNING - task text-to-video-synthesis input definition is missing
# WARNING:modelscope:task text-to-video-synthesis input definition is missing
# 2023-07-08 08:22:50,119 - modelscope - WARNING - task text-to-video-synthesis output keys are missing
# WARNING:modelscope:task text-to-video-synthesis output keys are missing
# output_video_path: /home/model-server/tmp/tmpjh4u5k0z.mp4

# %%
pip install opencv-python
