# %% [markdown]
# # BigVGAN
#
# A Universal Neural Vocoder with Large-Scale Training
#
# Repo is [here](https://github.com/NVIDIA/BigVGAN). Just follow the steps in the README.md file.

# %%
import os
os.environ['HTTP_PROXY'] = 'http://proxy.vmware.com:3128'
os.environ['HTTPS_PROXY'] = 'http://proxy.vmware.com:3128'

# %%
# !git clone https://github.com/NVIDIA/BigVGAN.git
# Out:
# Cloning into 'BigVGAN'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 59 (delta 19), reused 46 (delta 12), pack-reused 0
# Unpacking objects: 100% (59/59), 14.46 MiB | 4.62 MiB/s, done.

# %%
cd BigVGAN/
# Out:
# /home/jovyan/BigVGAN

# %%
pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.8/203.8 kB 542.8 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.7 MB/s eta 0:00:0000:0100:01m
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 6.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 9.8 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 9.2 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.0 MB/s eta 0:00:00ta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 5.6 MB/s eta 0:00:00:00:0100:01
# ...

# %%
cd BigVGAN/
# Out:
# /home/jovyan/BigVGAN

# %%
ls
# Out:
# LICENSE         alias_free_torch/  inference.py      parse_scripts/
# LibriTTS/       configs/           inference_e2e.py  requirements.txt
# README.md       env.py             meldataset.py     train.py
# activations.py  incl_licenses/     models.py         utils.py

# %%
# !python train.py \
--config configs/bigvgan_base_24khz_100band.json \
--input_wavs_dir LibriTTS \
--input_training_file LibriTTS/train-full.txt \
--input_validation_file LibriTTS/val-full.txt \
--list_input_unseen_wavs_dir LibriTTS LibriTTS \
--list_input_unseen_validation_file LibriTTS/dev-clean.txt LibriTTS/dev-other.txt \
--checkpoint_path exp/bigvgan
# Out:
# 2023-07-14 06:29:13.851608: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-14 06:29:14.970929: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Initializing Training Process..
# Batch size per GPU : 8
# Generator params: 14025154
# mpd_reshapes: [2, 3, 5, 7, 11]
# Discriminator mpd params: 41105770
# Discriminator mrd params: 280902
# BigVGAN(
#   (conv_pre): Conv1d(100, 512, kernel_size=(7,), stride=(1,), padding=(3,))
#   (ups): ModuleList(
#     (0): ModuleList(
#       (0): ConvTranspose1d(512, 256, kernel_size=(16,), stride=(8,), padding=(4,))
#     )
#     (1): ModuleList(
#       (0): ConvTranspose1d(256, 128, kernel_size=(16,), stride=(8,), padding=(4,))
#     )
# ...

# %%
pwd
# Out:
# '/home/jovyan/BigVGAN'

# %%
# !python inference.py \
--checkpoint_file /home/jovyan/model/bigvgan_base_24khz_100band/g_05000000.zip \
--input_wavs_dir /home/jovyan/data/input \
--output_dir /home/jovyan/data/output
# Out:
# Initializing Inference Process..
# /home/jovyan/model/bigvgan_base_24khz_100band/g_05000000.zip
# Loading '/home/jovyan/model/bigvgan_base_24khz_100band/g_05000000.zip'
# Complete.
# Removing weight norm...
# /home/jovyan/data/output/sentence_1_generated.wav
